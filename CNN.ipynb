# %% [markdown]
# # CNN Baseline Notebook
# This notebook implements and trains the baseline encoder model under our unified, leakage-safe LOBench replication pipeline.

# %%
# Mount Google Drive if running in Colab
try:
    from google.colab import drive
    drive.mount('/content/drive')
    import os
    os.chdir('/content/drive/MyDrive/JEPA_LOB/baselines')
    print('Mounted Google Drive and changed directory to baselines.')
except ImportError:
    print('Running locally or Google Drive mount skipped.')
# Out:
# Mounted at /content/drive
# Mounted Google Drive and changed directory to baselines.

# %%
# Install PyTorch Lightning if it is not present in the environment
# !pip install -q lightning pandas numpy torch
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 61.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 54.1 MB/s eta 0:00:00

# %%
from common import *
import torch
import torch.nn as nn
import torch.nn.functional as F

print('Libraries and common module imported successfully.')
# Out:
# Libraries and common module imported successfully.

# %%
class CNNEncoder(nn.Module):
    def __init__(self, n_features=40, latent_dim=256):
        super().__init__()
        self.conv1 = nn.Conv1d(n_features, 32, kernel_size=5, padding=2)
        self.conv2 = nn.Conv1d(32, 64, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm1d(32)
        self.bn2 = nn.BatchNorm1d(64)
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.proj = nn.Linear(64, latent_dim)

    def forward(self, x):  # x: [B, 100, 40]
        x = x.transpose(1, 2)                  # [B, 40, 100] -- Conv1d expects channels-first
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x).squeeze(-1)            # [B, 64]
        return self.proj(x)                     # [B, latent_dim]

# %%
model_name = 'CNN'
stocks = ['sz000001', 'sz000002', 'sz000858', 'sz300147', 'sz002415']
for stock in stocks:
    print(f'\n========================================')
    print(f'Starting experiment for Model: {model_name} | Stock: {stock}')
    print(f'========================================')
    run_experiment(
        encoder_class=CNNEncoder,
        model_name=model_name,
        stock=stock,
        latent_dim=256,
        max_epochs=100
    )
# Out:
# ========================================
# Starting experiment for Model: CNN | Stock: sz000001
# ========================================
# Loading data from data/sz000001-level10_processed.csv...
# Loaded shape: (1171534, 41)
# Columns and Level 10 ordering verified successfully.
# Detecting sessions (3-second continuous chunks)...
# Detected 488 sessions.
# Splitting train/val/test splits (80/10/10 by calendar dates)...
# Constructing sequence window indices (seq_len=100, stride=1)...
#
# --- Train/Val/Test Splits & Windows ---
# Split      | Rows       | Window Count
# Train      | 936254     | 897644
# Validation | 115231     | 110479
# Test       | 120049     | 115099
# ---------------------------------------
#
# Encoder parameters: 33,568
# Shared Decoder parameters: 4,756,896
# Total model parameters: 4,790,464
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:lightning.pytorch.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Found existing checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000001/last.ckpt. Resuming training...
# /usr/local/lib/python3.12/dist-packages/lightning/fabric/loggers/csv_logs.py:268: Experiment logs directory training_logs/CNN/sz000001 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000001 exists and is not empty.
# INFO: Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000001/last.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000001/last.ckpt
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:566: The dirpath has changed from '/content/drive/.shortcut-targets-by-id/1CU14Fp2kwwtsMDvchQKKm-sSCYR6c_rS/JEPA_LOB/baselines/checkpoints/CNN/sz000001' to '/content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000001', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ encoder │ CNNEncoder    │ 33.6 K │ train │     0 │
# │ 1 │ decoder │ SharedDecoder │  4.8 M │ train │     0 │
# │ 2 │ loss_fn │ MSELoss       │      0 │ train │     0 │
# │ 3 │ mae_fn  │ L1Loss        │      0 │ train │     0 │
# └───┴─────────┴───────────────┴────────┴───────┴───────┘
# Trainable params: 4.8 M
# Non-trainable params: 0
# Total params: 4.8 M
# Total estimated model params size (MB): 19.162
# Modules in train mode: 13
# Modules in eval mode: 0
# Total FLOPs: 0
# INFO: Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000001/last.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000001/last.ckpt
# Output()
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)`
# is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training loop finished in 7 seconds.
# Loading best checkpoint for evaluation: /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000001/best-v1.ckpt
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_mae          │    0.14804792404174805    │
# │         test_mse          │    0.08688131719827652    │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# === FINAL REPORT ===
# Model: CNN | Stock: sz000001
# Encoder params: 33,568
# Total params (encoder + shared decoder): 4,790,464
# Training time: 7s
# Test MSE: 0.0869
# Test MAE: 0.1480
# ====================
#
#
# ========================================
# Starting experiment for Model: CNN | Stock: sz000002
# ========================================
# Loading data from data/sz000002-level10_processed.csv...
# Loaded shape: (1171533, 41)
# Columns and Level 10 ordering verified successfully.
# Detecting sessions (3-second continuous chunks)...
# Detected 488 sessions.
# Splitting train/val/test splits (80/10/10 by calendar dates)...
# Constructing sequence window indices (seq_len=100, stride=1)...
#
# --- Train/Val/Test Splits & Windows ---
# Split      | Rows       | Window Count
# Train      | 936252     | 897642
# Validation | 115231     | 110479
# Test       | 120050     | 115100
# ---------------------------------------
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:lightning.pytorch.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /usr/local/lib/python3.12/dist-packages/lightning/fabric/loggers/csv_logs.py:268: Experiment logs directory training_logs/CNN/sz000002 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000002 exists and is not empty.
# INFO: Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000002/last.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000002/last.ckpt
# Encoder parameters: 33,568
# Shared Decoder parameters: 4,756,896
# Total model parameters: 4,790,464
# Found existing checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000002/last.ckpt. Resuming training...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:566: The dirpath has changed from '/content/drive/.shortcut-targets-by-id/1CU14Fp2kwwtsMDvchQKKm-sSCYR6c_rS/JEPA_LOB/baselines/checkpoints/CNN/sz000002' to '/content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000002', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ encoder │ CNNEncoder    │ 33.6 K │ train │     0 │
# │ 1 │ decoder │ SharedDecoder │  4.8 M │ train │     0 │
# │ 2 │ loss_fn │ MSELoss       │      0 │ train │     0 │
# │ 3 │ mae_fn  │ L1Loss        │      0 │ train │     0 │
# └───┴─────────┴───────────────┴────────┴───────┴───────┘
# Trainable params: 4.8 M
# Non-trainable params: 0
# Total params: 4.8 M
# Total estimated model params size (MB): 19.162
# Modules in train mode: 13
# Modules in eval mode: 0
# Total FLOPs: 0
# INFO: Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000002/last.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000002/last.ckpt
# Output()
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)`
# is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training loop finished in 3 seconds.
# Loading best checkpoint for evaluation: /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000002/best-v1.ckpt
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_mae          │    0.24874655902385712    │
# │         test_mse          │    0.2573736906051636     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# === FINAL REPORT ===
# Model: CNN | Stock: sz000002
# Encoder params: 33,568
# Total params (encoder + shared decoder): 4,790,464
# Training time: 3s
# Test MSE: 0.2574
# Test MAE: 0.2487
# ====================
#
#
# ========================================
# Starting experiment for Model: CNN | Stock: sz000858
# ========================================
# Loading data from data/sz000858-level10_processed.csv...
# Loaded shape: (1171563, 41)
# Columns and Level 10 ordering verified successfully.
# Detecting sessions (3-second continuous chunks)...
# Detected 488 sessions.
# Splitting train/val/test splits (80/10/10 by calendar dates)...
# Constructing sequence window indices (seq_len=100, stride=1)...
#
# --- Train/Val/Test Splits & Windows ---
# Split      | Rows       | Window Count
# Train      | 936267     | 897657
# Validation | 115246     | 110494
# Test       | 120050     | 115100
# ---------------------------------------
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:lightning.pytorch.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /usr/local/lib/python3.12/dist-packages/lightning/fabric/loggers/csv_logs.py:268: Experiment logs directory training_logs/CNN/sz000858 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000858 exists and is not empty.
# INFO: Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000858/last-v8.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000858/last-v8.ckpt
# Encoder parameters: 33,568
# Shared Decoder parameters: 4,756,896
# Total model parameters: 4,790,464
# Found existing checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000858/last-v8.ckpt. Resuming training...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:566: The dirpath has changed from '/content/drive/.shortcut-targets-by-id/1CU14Fp2kwwtsMDvchQKKm-sSCYR6c_rS/JEPA_LOB/baselines/checkpoints/CNN/sz000858' to '/content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000858', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ encoder │ CNNEncoder    │ 33.6 K │ train │     0 │
# │ 1 │ decoder │ SharedDecoder │  4.8 M │ train │     0 │
# │ 2 │ loss_fn │ MSELoss       │      0 │ train │     0 │
# │ 3 │ mae_fn  │ L1Loss        │      0 │ train │     0 │
# └───┴─────────┴───────────────┴────────┴───────┴───────┘
# Trainable params: 4.8 M
# Non-trainable params: 0
# Total params: 4.8 M
# Total estimated model params size (MB): 19.162
# Modules in train mode: 13
# Modules in eval mode: 0
# Total FLOPs: 0
# INFO: Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000858/last-v8.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000858/last-v8.ckpt
# Output()
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)`
# is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training loop finished in 3 seconds.
# Loading best checkpoint for evaluation: /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz000858/best-v8.ckpt
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_mae          │    0.13280880451202393    │
# │         test_mse          │    0.1918935924768448     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# === FINAL REPORT ===
# Model: CNN | Stock: sz000858
# Encoder params: 33,568
# Total params (encoder + shared decoder): 4,790,464
# Training time: 3s
# Test MSE: 0.1919
# Test MAE: 0.1328
# ====================
#
#
# ========================================
# Starting experiment for Model: CNN | Stock: sz300147
# ========================================
# Loading data from data/sz300147-level10_processed.csv...
# Loaded shape: (1171444, 41)
# Columns and Level 10 ordering verified successfully.
# Detecting sessions (3-second continuous chunks)...
# Detected 488 sessions.
# Splitting train/val/test splits (80/10/10 by calendar dates)...
# Constructing sequence window indices (seq_len=100, stride=1)...
#
# --- Train/Val/Test Splits & Windows ---
# Split      | Rows       | Window Count
# Train      | 936195     | 897585
# Validation | 115224     | 110472
# Test       | 120025     | 115075
# ---------------------------------------
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:lightning.pytorch.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /usr/local/lib/python3.12/dist-packages/lightning/fabric/loggers/csv_logs.py:268: Experiment logs directory training_logs/CNN/sz300147 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz300147 exists and is not empty.
# INFO: Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz300147/last.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz300147/last.ckpt
# Encoder parameters: 33,568
# Shared Decoder parameters: 4,756,896
# Total model parameters: 4,790,464
# Found existing checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz300147/last.ckpt. Resuming training...
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:566: The dirpath has changed from '/content/drive/.shortcut-targets-by-id/1CU14Fp2kwwtsMDvchQKKm-sSCYR6c_rS/JEPA_LOB/baselines/checkpoints/CNN/sz300147' to '/content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz300147', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ encoder │ CNNEncoder    │ 33.6 K │ train │     0 │
# │ 1 │ decoder │ SharedDecoder │  4.8 M │ train │     0 │
# │ 2 │ loss_fn │ MSELoss       │      0 │ train │     0 │
# │ 3 │ mae_fn  │ L1Loss        │      0 │ train │     0 │
# └───┴─────────┴───────────────┴────────┴───────┴───────┘
# Trainable params: 4.8 M
# Non-trainable params: 0
# Total params: 4.8 M
# Total estimated model params size (MB): 19.162
# Modules in train mode: 13
# Modules in eval mode: 0
# Total FLOPs: 0
# INFO: Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz300147/last.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz300147/last.ckpt
# Output()
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)`
# is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training loop finished in 4 seconds.
# Loading best checkpoint for evaluation: /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz300147/best.ckpt
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_mae          │    0.7665880918502808     │
# │         test_mse          │    10.281745910644531     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# === FINAL REPORT ===
# Model: CNN | Stock: sz300147
# Encoder params: 33,568
# Total params (encoder + shared decoder): 4,790,464
# Training time: 4s
# Test MSE: 10.2817
# Test MAE: 0.7666
# ====================
#
#
# ========================================
# Starting experiment for Model: CNN | Stock: sz002415
# ========================================
# Loading data from data/sz002415-level10_processed.csv...
# Loaded shape: (1171669, 41)
# Columns and Level 10 ordering verified successfully.
# Detecting sessions (3-second continuous chunks)...
# Detected 488 sessions.
# Splitting train/val/test splits (80/10/10 by calendar dates)...
# Constructing sequence window indices (seq_len=100, stride=1)...
#
# --- Train/Val/Test Splits & Windows ---
# Split      | Rows       | Window Count
# Train      | 936377     | 897767
# Validation | 115242     | 110490
# Test       | 120050     | 115100
# ---------------------------------------
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:lightning.pytorch.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /usr/local/lib/python3.12/dist-packages/lightning/fabric/loggers/csv_logs.py:268: Experiment logs directory training_logs/CNN/sz002415 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz002415 exists and is not empty.
# INFO: Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz002415/last-v1.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restoring states from the checkpoint path at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz002415/last-v1.ckpt
# Encoder parameters: 33,568
# Shared Decoder parameters: 4,756,896
# Total model parameters: 4,790,464
# Found existing checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz002415/last-v1.ckpt. Resuming training...
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ encoder │ CNNEncoder    │ 33.6 K │ train │     0 │
# │ 1 │ decoder │ SharedDecoder │  4.8 M │ train │     0 │
# │ 2 │ loss_fn │ MSELoss       │      0 │ train │     0 │
# │ 3 │ mae_fn  │ L1Loss        │      0 │ train │     0 │
# └───┴─────────┴───────────────┴────────┴───────┴───────┘
# Trainable params: 4.8 M
# Non-trainable params: 0
# Total params: 4.8 M
# Total estimated model params size (MB): 19.162
# Modules in train mode: 13
# Modules in eval mode: 0
# Total FLOPs: 0
# INFO: Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz002415/last-v1.ckpt
# INFO:lightning.pytorch.utilities.rank_zero:Restored all states from the checkpoint at /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz002415/last-v1.ckpt
# Output()
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)`
# is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training loop finished in 5209 seconds.
# Loading best checkpoint for evaluation: /content/drive/MyDrive/JEPA_LOB/baselines/checkpoints/CNN/sz002415/best-v1.ckpt
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_mae          │    0.16616497933864594    │
# │         test_mse          │    0.16535812616348267    │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# === FINAL REPORT ===
# Model: CNN | Stock: sz002415
# Encoder params: 33,568
# Total params (encoder + shared decoder): 4,790,464
# Training time: 5209s
# Test MSE: 0.1654
# Test MAE: 0.1662
# ====================
